# %%
#Importing Libraries

import rasterio
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import glob
import geopandas as gpd
from rasterio.features import shapes
from rasterio.mask import mask
import gdal
import osgeo
from shapely.geometry import box
from shapely.geometry import Polygon
import geopandas as gpd
from rasterio.mask import mask
import fiona

# %% [markdown]
# ### NO2
#
# Nitrogen dioxide (NO2) and nitrogen oxide (NO) together are usually referred to as nitrogen oxides (NOx = NO + NO2). They are important trace gases in the Earth’s atmosphere, present in both the troposphere and the stratosphere. They enter the atmosphere as a result of anthropogenic activities (notably fossil fuel combustion and biomass burning) and natural processes (such as microbiological processes in soils, wildfires and lightning). During daytime, i.e. in the presence of sunlight, a photochemical cycle involving ozone (O3) converts NO into NO2 (and vice versa) on a timescale of minutes, so that NO2 is a robust measure for concentrations of nitrogen oxides.

# %%
###read image
data1 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\NO2\2020-04-14-00_00_2020-04-14-23_59_Sentinel-5_NO2_Nitrogen_Dioxide.tiff")
phase1 = data1.read([1,2,3])
data2 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\NO2\2020-05-13-00 00_2020-05-13-23 59_Sentinel-5_NO2_Nitrogen_Dioxide.tiff")
phase2 = data2.read([1,2,3])
data3 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\NO2\2020-05-17-00 00_2020-05-17-23 59_Sentinel-5_NO2_Nitrogen_Dioxide.tiff")
phase3 = data3.read([1,2,3])
data4 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\NO2\2020-05-31-00 00_2020-05-31-23 59_Sentinel-5_NO2_Nitrogen_Dioxide.tiff")
phase4 = data4.read([1,2,3])
data5 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\NO2\2020-06-16-00 00_2020-06-16-23 59_Sentinel-5_NO2_Nitrogen_Dioxide.tiff")
phase5 = data5.read([1,2,3])

# %%
phase1 = np.moveaxis(phase1,0,-1)
plt.figure(figsize=(6,6))
plt.title('NO2 in Phase - 1',fontsize=18, fontweight='bold')
plt.imshow(phase1)
plt.colorbar(orientation='horizontal')

# %%
phase2 = np.moveaxis(phase2,0,-1)
plt.figure(figsize=(6,6))
plt.title('NO2 in Phase - 2',fontsize=18, fontweight='bold')
plt.imshow(phase2)
plt.colorbar(orientation='horizontal')

# %%
phase3 = np.moveaxis(phase3,0,-1)
plt.figure(figsize=(6,6))
plt.title('NO2 in Phase - 3',fontsize=18, fontweight='bold')
plt.imshow(phase3)
plt.colorbar(orientation='horizontal')

# %%
phase4 = np.moveaxis(phase4,0,-1)
plt.figure(figsize=(6,6))
plt.title('NO2 in Phase - 4',fontsize=18, fontweight='bold')
plt.imshow(phase4)
plt.colorbar(orientation='horizontal')

# %%
phase5 = np.moveaxis(phase5,0,-1)
plt.figure(figsize=(6,6))
plt.title('NO2 in Phase - 5',fontsize=18, fontweight='bold')
plt.imshow(phase5)
plt.colorbar(orientation='horizontal')

# %% [markdown]
# ### SO2
#
# Sulphur dioxide (SO2) enters the Earth’s atmosphere through both natural and anthropogenic processes. It plays a role in chemistry on a local and global scale and its impact ranges from short term pollution to effects on climate. Only about 30% of the emitted SO2 comes from natural sources; the majority is of anthropogenic origin. SO2 emissions adversely affect human health and air quality. SO2 has an effect on climate through radiative forcing, via the formation of sulphate aerosols. Volcanic SO2 emissions can also pose a threat to aviation, along with volcanic ash.

# %%
###read image
data1 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\SO2\2020-04-14-00 00_2020-04-14-23 59_Sentinel-5_SO2_Sulfur_Dioxide.tiff")
phase1 = data1.read([1,2,3])
data2 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\SO2\2020-05-03-00 00_2020-05-03-23 59_Sentinel-5_SO2_Sulfur_Dioxide.tiff")
phase2 = data2.read([1,2,3])
data3 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\SO2\2020-05-17-00 00_2020-05-17-23 59_Sentinel-5_SO2_Sulfur_Dioxide.tiff")
phase3 = data3.read([1,2,3])
data4 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\SO2\2020-05-31-00 00_2020-05-31-23 59_Sentinel-5_SO2_Sulfur_Dioxide.tiff")
phase4 = data4.read([1,2,3])
data5 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\SO2\2020-06-16-00 00_2020-06-16-23 59_Sentinel-5_SO2_Sulfur_Dioxide.tiff")
phase5 = data5.read([1,2,3])

# %%
phase1 = np.moveaxis(phase1,0,-1)
plt.figure(figsize=(6,6))
plt.title('SO2 in Phase - 1',fontsize=18, fontweight='bold')
plt.imshow(phase1)
plt.colorbar(orientation='horizontal')

# %%
phase2 = np.moveaxis(phase2,0,-1)
plt.figure(figsize=(6,6))
plt.title('SO2 in Phase - 2',fontsize=18, fontweight='bold')
plt.imshow(phase2)
plt.colorbar(orientation='horizontal')

# %%
phase3 = np.moveaxis(phase3,0,-1)
plt.figure(figsize=(6,6))
plt.title('SO2 in Phase - 3',fontsize=18, fontweight='bold')
plt.imshow(phase3)
plt.colorbar(orientation='horizontal')

# %%
phase4 = np.moveaxis(phase4,0,-1)
plt.figure(figsize=(6,6))
plt.title('SO2 in Phase - 4',fontsize=18, fontweight='bold')
plt.imshow(phase4)
plt.colorbar(orientation='horizontal')

# %%
phase5 = np.moveaxis(phase5,0,-1)
plt.figure(figsize=(6,6))
plt.title('SO2 in Phase - 5',fontsize=18, fontweight='bold')
plt.imshow(phase5)
plt.colorbar(orientation='horizontal')

# %% [markdown]
# ### CO
#
# Carbon monoxide (CO) is an important atmospheric trace gas for our understanding of tropospheric chemistry. In certain urban areas, it is a major atmospheric pollutant. Main sources of CO are combustion of fossil fuels, biomass burning, and atmospheric oxidation of methane and other hydrocarbons. Whereas fossil fuel combustion is the main source of CO at Northern mid-latitudes, the oxidation of isoprene and biomass burning play an important role in the tropics.

# %%
###read image
data1 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\CO\2020-04-14-00 00_2020-04-14-23 59_Sentinel-5_CO_Carbon_Monoxide.tiff")
phase1 = data1.read([1,2,3])
data2 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\CO\2020-05-03-00 00_2020-05-03-23 59_Sentinel-5_CO_Carbon_Monoxide.tiff")
phase2 = data2.read([1,2,3])
data3 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\CO\2020-05-17-00 00_2020-05-17-23 59_Sentinel-5_CO_Carbon_Monoxide.tiff")
phase3 = data3.read([1,2,3])
data4 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\CO\2020-05-31-00 00_2020-05-31-23 59_Sentinel-5_CO_Carbon_Monoxide.tiff")
phase4 = data4.read([1,2,3])
data5 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\CO\2020-06-16-00 00_2020-06-16-23 59_Sentinel-5_CO_Carbon_Monoxide.tiff")
phase5 = data5.read([1,2,3])

# %%
phase1 = np.moveaxis(phase1,0,-1)
plt.figure(figsize=(6,6))
plt.title('CO in Phase - 1',fontsize=18, fontweight='bold')
plt.imshow(phase1)
plt.colorbar(orientation='horizontal')

# %%
phase2 = np.moveaxis(phase2,0,-1)
plt.figure(figsize=(6,6))
plt.title('CO in Phase - 2',fontsize=18, fontweight='bold')
plt.imshow(phase2)
plt.colorbar(orientation='horizontal')

# %%
phase3 = np.moveaxis(phase3,0,-1)
plt.figure(figsize=(6,6))
plt.title('CO in Phase - 3',fontsize=18, fontweight='bold')
plt.imshow(phase3)
plt.colorbar(orientation='horizontal')

# %%
phase4 = np.moveaxis(phase4,0,-1)
plt.figure(figsize=(6,6))
plt.title('CO in Phase - 4',fontsize=18, fontweight='bold')
plt.imshow(phase4)
plt.colorbar(orientation='horizontal')

# %%
phase5 = np.moveaxis(phase5,0,-1)
plt.figure(figsize=(6,6))
plt.title('CO in Phase - 5',fontsize=18, fontweight='bold')
plt.imshow(phase5)
plt.colorbar(orientation='horizontal')

# %% [markdown]
# ### O3
#
# Ozone (O3) is of crucial importance for the equilibrium of the Earth atmosphere. In the stratosphere, the ozone layer shields the biosphere from dangerous solar ultraviolet radiation. In the troposphere, it acts as an efficient cleansing agent, but at high concentration it also becomes harmful to the health of humans, animals, and vegetation. Ozone is also an important greenhouse-gas contributor to ongoing climate change.

# %%
###read image
data1 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\O3\2020-04-14-00 00_2020-04-14-23 59_Sentinel-5_O3_Ozone.tiff")
phase1 = data1.read([1,2,3])
data2 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\O3\2020-05-03-00 00_2020-05-03-23 59_Sentinel-5_O3_Ozone.tiff")
phase2 = data2.read([1,2,3])
data3 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\O3\2020-05-17-00 00_2020-05-17-23 59_Sentinel-5_O3_Ozone.tiff")
phase3 = data3.read([1,2,3])
data4 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\O3\2020-05-31-00 00_2020-05-31-23 59_Sentinel-5_O3_Ozone.tiff")
phase4 = data4.read([1,2,3])
data5 = rasterio.open(r"C:\Deepali_pro\Covid_19_impact\Air_polution\O3\2020-06-16-00 00_2020-06-16-23 59_Sentinel-5_O3_Ozone.tiff")
phase5 = data5.read([1,2,3])

# %%
phase1 = np.moveaxis(phase1,0,-1)
plt.figure(figsize=(6,6))
plt.title('O3 in Phase - 1',fontsize=18, fontweight='bold')
plt.imshow(phase1)
plt.colorbar(orientation='horizontal')

# %%
phase2 = np.moveaxis(phase2,0,-1)
plt.figure(figsize=(6,6))
plt.title('O3 in Phase - 2',fontsize=18, fontweight='bold')
plt.imshow(phase2)
plt.colorbar(orientation='horizontal')

# %%
phase3 = np.moveaxis(phase3,0,-1)
plt.figure(figsize=(6,6))
plt.title('O3 in Phase - 3',fontsize=18, fontweight='bold')
plt.imshow(phase3)
plt.colorbar(orientation='horizontal')

# %%
phase4 = np.moveaxis(phase4,0,-1)
plt.figure(figsize=(6,6))
plt.title('O3 in Phase - 4',fontsize=18, fontweight='bold')
plt.imshow(phase4)
plt.colorbar(orientation='horizontal')

# %%
phase5 = np.moveaxis(phase5,0,-1)
plt.figure(figsize=(6,6))
plt.title('O3 in Phase - 5',fontsize=18, fontweight='bold')
plt.imshow(phase5)
plt.colorbar(orientation='horizontal')
